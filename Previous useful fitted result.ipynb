# %%
from matplotlib import pyplot as plt
import numpy as np
import os

# %%
c_913 = [ 1.7430e+05-2.2979e+03j, -1.4135e+04-2.7447e+05j, 3.0792e+04+3.0612e+04j, -1.6718e+04+6.9974e+04j, 8.5940e-07-2.1062e-07j]
cc_913 = [ 1.7430e+05+2.2979e+03j, -1.4135e+04+2.7447e+05j, 3.0792e+04-3.0612e+04j, -1.6718e+04-6.9974e+04j, 8.5940e-07+2.1062e-07j]
#torch.exp(-self.eta[:self.dim_r] * r)
gamma_913 = [-2.1681e-04-5.7328e-05j, -1.0436e+00-2.4178e-01j, -6.3217e-01-3.0236e-01j, -1.2028e+00-5.8873e-01j, -3.7125e-04-3.5081e-05j]

# %%
c_913_2 = [4.5211e+05-9.4560e+04j,  1.7437e+05+2.3538e+05j, 3.6712e+04+3.3364e+05j, -4.8892e+05-2.3216e+05j, -3.7842e-07-2.1067e-07j]
cc_913_2 = [4.5211e+05+9.4560e+04j,  1.7437e+05-2.3538e+05j, 3.6712e+04-3.3364e+05j, -4.8892e+05+2.3216e+05j, -3.7842e-07+2.1067e-07j]
#torch.exp(-self.eta[:self.dim_r] * r)
gamma_913_2 =[-1.2372e+00-7.7720e-01j,-3.4039e-04+1.6330e-04j, -1.1732e+00-6.3377e-01j, -1.1543e+00-7.6264e-01j, -3.3239e-04-5.7047e-05j]

# %%
c_915 = [0.7162+0.4623j, 1.3345+1.1421j, 0.4392-0.3948j, 0.5253+1.4037j, 0.6031-0.2107j]
cc_915 = [0.7162-0.4623j, 1.3345-1.1421j, 0.4392+0.3948j, 0.5253-1.4037j, 0.6031+0.2107j]
gamma_915 = [-9.8126e-01+5.5376e-01j, -2.2642e-04-1.1396e-04j, -4.3707e-02+1.3549e-03j, -9.2645e-04-1.7521e-06j, -2.8699e-04-2.4946e-05j]

# %%
c_915_2 = [0.4824+0.1275j,  0.7834+0.3248j,  1.0219+0.5140j,  0.7252+1.0792j, -0.4197-0.2107j]
cc_915_2 = [0.4824-0.1275j,  0.7834-0.3248j,  1.0219-0.5140j,  0.7252-1.0792j, -0.4197+0.2107j]
gamma_915_2 [-3.1809e-02-1.3308e-05j, -4.5481e-04+2.8825e-07j,-1.7818e-04-9.3342e-05j, -7.1408e-01+3.3420e-01j,-2.8480e-04+3.2784e-05j]

# %%
c_922 = [9.5915-0.9188j,  9.4428-0.9614j, 10.3957-8.1284j, 29.3786-0.0607j]
cc_922 = [9.5915+0.9188j,  9.4428+0.9614j, 10.3957+8.1284j, 29.3786+0.0607j]
gamma_922 = [1.3934+0.0724j,  0.8057-0.2269j,  0.0662-0.0512j, 38.8305+0.0545j]

# %%
c_922_2 = [28.0850-0.1691j,  7.7881-3.5182j, 16.1874-2.1386j,  6.3672-4.2557j]
cc_922_2 = [28.0850+0.1691j,  7.7881+3.5182j, 16.1874+2.1386j,  6.3672+4.2557j]
gamma_922_2 = [3.8431e+01-0.0310j, 1.6567e-01-0.1511j, 1.5471e+00-0.1895j, 3.8162e-02-0.0447j]

# %%
#成功跑出来的
gamma_pade_100 = [ -4.5563e-04+0.0000e+00j,-1.9898e-03+0.0000e+00j, -4.1036e-03+0.0000e+00j, -1.1438e-02+0.0000e+00j]

# %%
from matplotlib import pyplot as plt
import numpy as np
import os


fig, axes = plt.subplots(1, 2, figsize=(8,3), tight_layout=True)
_t_space = np.linspace(0, 4000, num=1000, dtype=complex)
for  _c, _g, ptn in [([cc for cc in c_1013_1], gamma_1013_1, 'r'), 
                     (c_pade_300 , gamma_pade_300, 'b'),
                     (c_pade_300[:1], gamma_pade_300[:1], 'g')]:
    ct = np.zeros_like(_t_space)
    for _ci, _gi in zip(_c, _g):
        ct += _ci * np.exp(_gi * _t_space)
        
    axes[0].plot(_t_space.real, ct.real, ptn)
    axes[1].plot(_t_space.real, ct.imag, ptn)
#* np.sqrt(219.47463050000002)
#axes[0].set_xscale('log')
#axes[1].set_xscale('log')
plt.show()

# %%
file0 = open('0test_929.txt', 'r')
file1 = open('1test929.txt', 'r')
file2 = open('Pade_drude_dynamic.txt', 'r')

dr0 = np.loadtxt(file0 ,delimiter = " ", dtype = complex)
dr1 = np.loadtxt(file1 ,delimiter = " ", dtype = complex)
dr2 = np.loadtxt(file2 ,delimiter = " ", dtype = complex)

# %%
plt.figure()#figsize = (10,5))
ax1 = plt.subplot()#121)
ax1.set_title('Test0 and Test 1')
#ax1.set_xscale('log')
time0 = dr0[:, 0].real
rdo00_0 = dr0[:, 1].real
rdo01_0 = (abs(dr0[:, 2])**2)
time1 = dr1[:, 0].real
rdo00_1 = dr1[:, 1].real
rdo01_1 = (abs(dr1[:, 2])**2)
time2 = dr2[:, 0].real
rdo00_2 = dr2[:, 1].real
rdo01_2 = (abs(dr2[:, 2])**2)
#ax1.plot(time0, rdo00_0)
ax1.plot(time0, rdo01_0, label = "fit")
ax1.plot(time2, rdo01_2, c = "r", label = "original")
ax1.legend()

os.environ["KMP_DUPLICATE_LIB_OK"] = "True"
plt.show()

# %%
#big function
c_1013 = [0.7713-0.1505j, 1.0284+0.0558j,  0.3651-0.6079j, 0.4256-0.6093j]
cc_1013 =  [1.0284-0.0558j, 0.7713+0.1505j, 0.4256+0.6093j, 0.3651+0.6079j]
gamma_1013 = [ -0.0537+0.0011j,  -0.0537-0.0011j, -27.0080-0.7194j, -27.0080+0.7194j]
#small function # 4.7398e-07-4.1520e-07j | +4.7398e-07+4.1520e-07j | -4.5563e-04+0.0000e+00j
c_1013_1 = [7.7126e-07-1.5049e-07j, 1.0284e-06+5.5751e-08j,  3.6510e-07-6.0794e-07j, 4.2557e-07-6.0928e-07j]
cc_1013_1 =  [1.0284e-06-5.5751e-08j, 7.7126e-07+1.5049e-07j, 4.2557e-07+6.0928e-07j, 3.6510e-07+6.0794e-07j]
gamma_1013_1 = [-0.0537e-03+0.0011e-03j,  -0.0537e-03-0.0011e-03j, -27.0080e-03-0.7194e-03j, -27.0080e-03+0.7194e-03j]

# %%
file3 = open('0test1014.txt', 'r')
dr3 = np.loadtxt(file3 ,delimiter = " ", dtype = complex)

# %%
plt.figure()#figsize = (10,5))
ax1 = plt.subplot()#121)
ax1.set_title('Dynamics')
#ax1.set_xscale('log')
time3 = dr3[:, 0].real
rdo00_3 = dr3[:, 1].real
rdo01_3 = (abs(dr3[:, 2])**2)
time2 = dr2[:, 0].real
rdo00_2 = dr2[:, 1].real
rdo01_2 = (abs(dr2[:, 2])**2)
#ax1.plot(time0, rdo00_0)
ax1.plot(time3, rdo01_3, label = "fit")
ax1.plot(time2, rdo01_2, c = "r", label = "Pade Method")
ax1.legend()

plt.show()

# %%
# with 1 degree of brownian and drude
#big function
c_1014 = [1.7366+0.3291j, 0.3121+0.5260j, 10.5501-0.1195j, 0.1550-0.1084j]
cc_1014 =  [0.3121-0.5260j, 1.7366-0.3291j,0.1550+0.1084j, 10.5501+0.1195j]
gamma_1014 = [-0.0685-0.0024j, -0.0685+0.0024j, -0.0096-1.0002j, -0.0096+1.0002j]
#small scale
c_1014 = [1.7366e-6+0.3291e-6j, 0.3121e-6+0.5260e-6j, 10.5501e-6-0.1195e-6j, 0.1550e-6-0.1084e-6j]
cc_1014 =  [0.3121e-6-0.5260e-6j, 1.7366e-6-0.3291e-6j,0.1550e-6+0.1084e-6j, 10.5501e-6+0.1195e-6j]
gamma_1014 = [-0.0685e-3-0.0024e-3j, -0.0685e-3+0.0024e-3j, -0.0096e-3-1.0002e-3j, -0.0096e-3+1.0002e-3j]

# %%
file4 = open('1d1b_1014.txt', 'r')
dr4 = np.loadtxt(file4 ,delimiter = " ", dtype = complex)
file5 = open('1d1b_dynamic.txt', 'r')
dr5 = np.loadtxt(file5 ,delimiter = " ", dtype = complex)

# %%
plt.figure()#figsize = (10,5))
ax1 = plt.subplot()#121)
ax1.set_title('Dynamics')
#ax1.set_xscale('log')
time5 = dr5[:, 0].real
rdo00_5 = dr5[:, 1].real
rdo01_5 = (abs(dr5[:, 2])**2)
time4 = dr4[:, 0].real
rdo00_4 = dr4[:, 1].real
rdo01_4 = (abs(dr4[:, 2])**2)
ax1.plot(time5, rdo01_5, label = "fit")
ax1.plot(time4, rdo01_4, c = "r", label = "Pade Method")
ax1.legend()

plt.show()

# %%
file5 = open('new1d4b_ft.txt', 'r')
dr5 = np.loadtxt(file5 ,delimiter = " ", dtype = complex)
file2 = open('Pade_drude_dynamic.txt', 'r')
dr2 = np.loadtxt(file2 ,delimiter = " ", dtype = complex)


plt.figure()#figsize = (10,5))
ax1 = plt.subplot()#121)
ax1.set_title('Dynamics')
#ax1.set_xscale('log')
time5 = dr5[:, 0].real
rdo00_5 = dr5[:, 1].real
rdo01_5 = (abs(dr5[:, 2])**2)
time2 = dr2[:, 0].real
rdo00_2 = dr2[:, 1].real
rdo01_2 = (abs(dr2[:, 2])**2)
ax1.plot(time5, rdo01_5, label = "fit")
ax1.plot(time2, rdo01_2, c = "r", label = "original")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
